# %% [markdown]
# The workflow should define explicitly:
# I1. the graph G = (V, E);
# I2. the node and edge weights;
# I3. the problem-specific sets or annotations;
# I4. the mathematical formulation parameters;
# I5. the solver hyperparameters;
# I6. the random seed;
# I7. the experiment identifier.
#
# The workflow should save:
# O1. the generated or loaded instance;
# O2. the full formulation data;
# O3. the solver outputs;
# O4. the decoded solutions;
# O5. the metrics;
# O6. the plots;
# O7. the experiment log and configuration file.
